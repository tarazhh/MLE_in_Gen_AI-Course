# %% [markdown]
# #Building Your First Voice Agent - Class 9 Interactive Tutorial
# ================================================================
# This notebook will guide you through creating a complete voice agent from scratch!
#
#
# # 🎯 Building Your First Voice Agent
#
# Welcome to an exciting journey into the world of voice technology! In this notebook, you'll learn to build your own voice agent that can:
# - 🎤 Listen to your voice (Speech Recognition)
# - 🧠 Understand what you're asking
# - 🗣️ Respond with a voice (Text-to-Speech)
#
# By the end of this tutorial, you'll have created your own personal assistant!
#
#
# ## 📚 What You'll Learn
#
# 1. **Speech Recognition (ASR)** - How computers "hear" and understand speech
# 2. **Text-to-Speech (TTS)** - How computers can talk back to you
# 3. **Natural Language Processing** - How computers understand meaning
# 4. **Integration** - Putting it all together into a working voice agent
#
# Let's start our journey! 🚀
#
#
# ## 🛠️ Step 1: Setting Up Our Tools
# First, we need to install the libraries that will help us build our voice agent.
#
# **What each library does:**
# - `speech_recognition`: Converts your speech to text (ASR)
# - `pyttsx3`: Converts text to speech (TTS)
# - `pyaudio`: Handles audio input/output
# - `requests`: Gets information from the internet
# - `datetime`: Works with dates and times

# %%
# Install required libraries (run this cell first!)
import subprocess
import sys

def install_package(package):
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        print(f"✅ {package} installed successfully!")
    except subprocess.CalledProcessError:
        print(f"❌ Failed to install {package}")

# List of packages we need
packages = [
    "speechrecognition",
    "pyttsx3", 
    "pyaudio",
    "requests",
    "wikipedia"
]

print("🔧 Installing required packages...")
for package in packages:
    install_package(package)

print("\n🎉 All packages installed! Let's start coding!")
# Out:
# 🔧 Installing required packages...
# Collecting speechrecognition
#   Downloading speechrecognition-3.14.3-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: typing-extensions in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from speechrecognition) (4.14.0)
# Downloading speechrecognition-3.14.3-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 25.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: speechrecognition
# Successfully installed speechrecognition-3.14.3
# ✅ speechrecognition installed successfully!
# Collecting pyttsx3
#   Downloading pyttsx3-2.98-py3-none-any.whl.metadata (3.8 kB)
# Collecting pyobjc>=2.4 (from pyttsx3)
#   Downloading pyobjc-11.1-py3-none-any.whl.metadata (25 kB)
# Collecting pyobjc-core==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_core-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-libdispatch==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_libdispatch-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-libxpc==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_libxpc-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Accessibility==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_accessibility-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AdServices==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_adservices-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-AdSupport==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_adsupport-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-AppTrackingTransparency==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_apptrackingtransparency-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AudioVideoBridging==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_audiovideobridging-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AuthenticationServices==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_authenticationservices-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AutomaticAssessmentConfiguration==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_automaticassessmentconfiguration-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AVKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_avkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AVFoundation==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_avfoundation-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-AVRouting==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_avrouting-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Accounts==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_accounts-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AddressBook==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_addressbook-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-AppleScriptKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_applescriptkit-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AppleScriptObjC==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_applescriptobjc-11.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-ApplicationServices==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_applicationservices-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-Automator==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_automator-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-BackgroundAssets==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_backgroundassets-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-BrowserEngineKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_browserenginekit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-BusinessChat==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_businesschat-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CFNetwork==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_cfnetwork-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-CalendarStore==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_calendarstore-11.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-CallKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_callkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Carbon==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_carbon-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Cinematic==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_cinematic-11.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-ClassKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_classkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CloudKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_cloudkit-11.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-Cocoa==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_cocoa-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Collaboration==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_collaboration-11.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-ColorSync==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_colorsync-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Contacts==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_contacts-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-ContactsUI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_contactsui-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CoreAudio==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coreaudio-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreAudioKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coreaudiokit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CoreBluetooth==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_corebluetooth-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CoreData==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coredata-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-CoreHaptics==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_corehaptics-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreLocation==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_corelocation-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-CoreMedia==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coremedia-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreMediaIO==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coremediaio-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreMIDI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coremidi-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreML==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coreml-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreMotion==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coremotion-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreServices==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coreservices-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-CoreSpotlight==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_corespotlight-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreText==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_coretext-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-CoreWLAN==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_corewlan-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CryptoTokenKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_cryptotokenkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DataDetection==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_datadetection-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-DeviceCheck==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_devicecheck-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DeviceDiscoveryExtension==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_devicediscoveryextension-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DictionaryServices==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_dictionaryservices-11.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-DiscRecording==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_discrecording-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-DiscRecordingUI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_discrecordingui-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DiskArbitration==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_diskarbitration-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-DVDPlayback==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_dvdplayback-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-EventKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_eventkit-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ExceptionHandling==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_exceptionhandling-11.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-ExecutionPolicy==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_executionpolicy-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ExternalAccessory==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_externalaccessory-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ExtensionKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_extensionkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-FileProvider==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_fileprovider-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-FileProviderUI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_fileproviderui-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-FSEvents==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_fsevents-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-FSKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_fskit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-FinderSync==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_findersync-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-GameCenter==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_gamecenter-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-GameController==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_gamecontroller-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-HealthKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_healthkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-InputMethodKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_inputmethodkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-ImageCaptureCore==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_imagecapturecore-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Intents==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_intents-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-IntentsUI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_intentsui-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-InstallerPlugins==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_installerplugins-11.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-InstantMessage==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_instantmessage-11.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-IOBluetooth==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_iobluetooth-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-IOBluetoothUI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_iobluetoothui-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-IOSurface==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_iosurface-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-KernelManagement==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_kernelmanagement-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-LatentSemanticMapping==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_latentsemanticmapping-11.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-LaunchServices==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_launchservices-11.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-LinkPresentation==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_linkpresentation-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-LocalAuthentication==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_localauthentication-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-LocalAuthenticationEmbeddedUI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_localauthenticationembeddedui-11.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-MailKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_mailkit-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-MapKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_mapkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-MediaAccessibility==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_mediaaccessibility-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MediaExtension==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_mediaextension-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MediaLibrary==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_medialibrary-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MediaPlayer==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_mediaplayer-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-MediaToolbox==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_mediatoolbox-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Metal==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_metal-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-MetalFX==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_metalfx-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-MetalKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_metalkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MetalPerformanceShaders==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_metalperformanceshaders-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MetalPerformanceShadersGraph==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_metalperformanceshadersgraph-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MetricKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_metrickit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-MLCompute==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_mlcompute-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-ModelIO==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_modelio-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MultipeerConnectivity==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_multipeerconnectivity-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-NaturalLanguage==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_naturallanguage-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-NetFS==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_netfs-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Network==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_network-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-NetworkExtension==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_networkextension-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-NotificationCenter==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_notificationcenter-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-OpenDirectory==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_opendirectory-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-OSAKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_osakit-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-OSLog==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_oslog-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-PassKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_passkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-PencilKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_pencilkit-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-PHASE==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_phase-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Photos==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_photos-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-PhotosUI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_photosui-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-PreferencePanes==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_preferencepanes-11.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-PushKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_pushkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Quartz==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_quartz-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Collecting pyobjc-framework-QuickLookThumbnailing==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_quicklookthumbnailing-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ReplayKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_replaykit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-SafetyKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_safetykit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SafariServices==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_safariservices-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-ScreenSaver==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_screensaver-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ScreenTime==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_screentime-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-ScriptingBridge==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_scriptingbridge-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-Security==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_security-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-SecurityFoundation==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_securityfoundation-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SecurityInterface==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_securityinterface-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SecurityUI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_securityui-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SearchKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_searchkit-11.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ServiceManagement==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_servicemanagement-11.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-ShazamKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_shazamkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Social==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_social-11.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Speech==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_speech-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-SpriteKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_spritekit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-StoreKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_storekit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-SyncServices==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_syncservices-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-SystemConfiguration==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_systemconfiguration-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-WebKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_webkit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-GameKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_gamekit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-GameplayKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_gameplaykit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SceneKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_scenekit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SensitiveContentAnalysis==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_sensitivecontentanalysis-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SharedWithYouCore==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_sharedwithyoucore-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SharedWithYou==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_sharedwithyou-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SoundAnalysis==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_soundanalysis-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-ScreenCaptureKit==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_screencapturekit-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Symbols==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_symbols-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-SystemExtensions==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_systemextensions-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ThreadNetwork==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_threadnetwork-11.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-UniformTypeIdentifiers==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_uniformtypeidentifiers-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-UserNotifications==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_usernotifications-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-UserNotificationsUI==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_usernotificationsui-11.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-VideoSubscriberAccount==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_videosubscriberaccount-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-VideoToolbox==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_videotoolbox-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Virtualization==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_virtualization-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Vision==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_vision-11.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-iTunesLibrary==11.1 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ituneslibrary-11.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Downloading pyttsx3-2.98-py3-none-any.whl (34 kB)
# Downloading pyobjc-11.1-py3-none-any.whl (4.2 kB)
# Downloading pyobjc_core-11.1-cp311-cp311-macosx_10_9_universal2.whl (671 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.1/671.1 kB 3.4 MB/s eta 0:00:00-:--:--
# Downloading pyobjc_framework_accessibility-11.1-cp311-cp311-macosx_10_9_universal2.whl (11 kB)
# Downloading pyobjc_framework_accounts-11.1-py2.py3-none-any.whl (5.1 kB)
# Downloading pyobjc_framework_addressbook-11.1-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Downloading pyobjc_framework_adservices-11.1-py2.py3-none-any.whl (3.5 kB)
# Downloading pyobjc_framework_adsupport-11.1-py2.py3-none-any.whl (3.4 kB)
# Downloading pyobjc_framework_applescriptkit-11.1-py2.py3-none-any.whl (4.3 kB)
# Downloading pyobjc_framework_applescriptobjc-11.1-py2.py3-none-any.whl (4.4 kB)
kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (pyproject.toml): started
#   Building wheel for pyaudio (pyproject.toml): finished with status 'error'
# Failed to build pyaudio
# ❌ Failed to install pyaudio
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [27 lines of output]
#       /private/var/folders/73/v36xqm_16qlckbh0hgrshdr40000gn/T/pip-build-env-yzprquzs/overlay/lib/python3.11/site-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-14.3-arm64-cpython-311/pyaudio
#       copying src/pyaudio/__init__.py -> build/lib.macosx-14.3-arm64-cpython-311/pyaudio
#       running build_ext
#       building 'pyaudio._portaudio' extension
#       creating build/temp.macosx-14.3-arm64-cpython-311/src/pyaudio
#       clang -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -DMACOS=1 -I/usr/local/include -I/usr/include -I/opt/homebrew/include "-I/Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/include" -I/Users/scottlai/.pyenv/versions/3.11.8/include/python3.11 -c src/pyaudio/device_api.c -o build/temp.macosx-14.3-arm64-cpython-311/src/pyaudio/device_api.o
#       src/pyaudio/device_api.c:9:10: fatal error: 'portaudio.h' file not found
#           9 | #include "portaudio.h"
#             |          ^~~~~~~~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pyaudio
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (pyaudio)
# Requirement already satisfied: requests in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from requests) (2025.4.26)
# ✅ requests installed successfully!
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting beautifulsoup4 (from wikipedia)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from wikipedia) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.4.26)
# Collecting soupsieve>1.2 (from beautifulsoup4->wikipedia)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/scottlai/Library/Mobile Documents/com~apple~CloudDocs/Desktop/work/inferenceAI/.venv/lib/python3.11/site-packages (from beautifulsoup4->wikipedia) (4.14.0)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (pyproject.toml): started
#   Building wheel for wikipedia (pyproject.toml): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11757 sha256=d88b4bad3837c5f99fec822e6aaffb0932ecdac54fb8c5efee155b7ee5338959
#   Stored in directory: /Users/scottlai/Library/Caches/pip/wheels/8f/ab/cb/45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# Installing collected packages: soupsieve, beautifulsoup4, wikipedia
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [wikipedia]
# Successfully installed beautifulsoup4-4.13.4 soupsieve-2.7 wikipedia-1.4.0
# ✅ wikipedia installed successfully!
#
# 🎉 All packages installed! Let's start coding!

# %% [markdown]
# # 🎤 Step 2: Understanding Speech Recognition (ASR)
# Speech Recognition is like giving your computer ears! Let's see how it works.
#
# The Process:
#
# 1. Your voice creates sound waves
#
# 2. Microphone converts sound waves to electrical signals
#
# 3. Computer converts signals to digital data
#
# 4. AI analyzes the data and finds words
#
# 5. Returns text that matches your speech

# %%
# ! brew install portaudio
# ! pip install pyaudio

# %%
import speech_recognition as sr
import time

# Create our speech recognizer
print("🎤 Creating Speech Recognizer...")
recognizer = sr.Recognizer()

# Let's test if our microphone works
def test_microphone():
    """Test if our microphone is working"""
    print("\n🔍 Testing microphone...")
    
    # Get list of available microphones
    mic_list = sr.Microphone.list_microphone_names()
    print(f"📱 Found {len(mic_list)} microphones:")
    
    for i, name in enumerate(mic_list[:3]):  # Show first 3
        print(f"  {i}: {name}")
    
    # Test with default microphone
    try:
        with sr.Microphone() as source:
            print("🎙️ Microphone is working!")
            print("📊 Adjusting for background noise... (2 seconds)")
            recognizer.adjust_for_ambient_noise(source, duration=2)
            print("✅ Microphone setup complete!")
            return True
    except Exception as e:
        print(f"❌ Microphone error: {e}")
        return False

# Test our setup
mic_working = test_microphone()
# Out:
# 🎤 Creating Speech Recognizer...
#
# 🔍 Testing microphone...
# 📱 Found 9 microphones:
#   0: Yeti Stereo Microphone
#   1: Yeti Stereo Microphone
#   2: USB Audio
# 🎙️ Microphone is working!
# 📊 Adjusting for background noise... (2 seconds)
# ✅ Microphone setup complete!

# %% [markdown]
# ## 🧪 Experiment 1: Your First Speech Recognition
#
# Let's try converting your speech to text! This is the foundation of all voice agents.

# %%
def listen_once():
    """Listen to user speech and convert to text"""
    if not mic_working:
        print("❌ Microphone not working. Please check your setup.")
        return "microphone not working"
    
    print("\n🎤 EXPERIMENT: Speech to Text")
    print("=" * 40)
    print("📢 Instructions:")
    print("1. Click 'Run' on this cell")
    print("2. When you see 'Listening...', start speaking")
    print("3. Speak clearly for 3-5 seconds")
    print("4. Watch the magic happen!")
    print()
    
    try:
        with sr.Microphone() as source:
            print("🎧 Listening... Speak now!")
            print("(Speak clearly for 3-5 seconds)")
            
            # Listen for audio with timeout
            audio = recognizer.listen(source, timeout=10, phrase_time_limit=5)
            print("🔄 Processing your speech...")
            
            # Convert speech to text using Google's free service
            text = recognizer.recognize_google(audio)
            
            print(f"\n✨ SUCCESS! You said: '{text}'")
            print(f"📝 Text length: {len(text)} characters")
            return text
            
    except sr.WaitTimeoutError:
        print("⏰ No speech detected. Try speaking louder!")
        return ""
    except sr.UnknownValueError:
        print("🤔 Could not understand the audio. Try speaking more clearly!")
        return ""
    except sr.RequestError as e:
        print(f"🌐 Internet connection error: {e}")
        return ""
    except Exception as e:
        print(f"❌ Unexpected error: {e}")
        return ""

# Try it now!
user_speech = listen_once()
# Out:
# 🎤 EXPERIMENT: Speech to Text
# ========================================
# 📢 Instructions:
# 1. Click 'Run' on this cell
# 2. When you see 'Listening...', start speaking
# 3. Speak clearly for 3-5 seconds
# 4. Watch the magic happen!
#
# 🎧 Listening... Speak now!
# (Speak clearly for 3-5 seconds)
# 🔄 Processing your speech...
#
# ✨ SUCCESS! You said: 'hello how's it going'
# 📝 Text length: 20 characters

# %% [markdown]
# ## 🎯 Challenge 1: Test Different Scenarios
#
# Let's see how well speech recognition works in different situations!

# %%
def speech_recognition_challenge():
    """Test speech recognition with different challenges"""
    print("🏆 SPEECH RECOGNITION CHALLENGE")
    print("=" * 50)
    
    challenges = [
        "Say a simple word like 'hello'",
        "Say a long sentence about your favorite hobby",
        "Try speaking very quietly",
        "Try speaking very fast",
        "Say some numbers like 'twelve thirty-four'"
    ]
    
    results = []
    
    for i, challenge in enumerate(challenges, 1):
        print(f"\n📝 Challenge {i}: {challenge}")
        input("   Press Enter when ready to speak...")
        
        result = listen_once()
        results.append(result)
        
        if result:
            print(f"   ✅ Result: '{result}'")
        else:
            print("   ❌ No result")
            
        print("-" * 30)
    
    print("\n📊 CHALLENGE SUMMARY:")
    for i, result in enumerate(results, 1):
        status = "✅ Success" if result else "❌ Failed"
        print(f"Challenge {i}: {status}")
    
    return results

# run the challenge!
challenge_results = speech_recognition_challenge()
# Out:
# 🏆 SPEECH RECOGNITION CHALLENGE
# ==================================================
#
# 📝 Challenge 1: Say a simple word like 'hello'
#
# 🎤 EXPERIMENT: Speech to Text
# ========================================
# 📢 Instructions:
# 1. Click 'Run' on this cell
# 2. When you see 'Listening...', start speaking
# 3. Speak clearly for 3-5 seconds
# 4. Watch the magic happen!
#
# 🎧 Listening... Speak now!
# (Speak clearly for 3-5 seconds)
# 🔄 Processing your speech...
#
# ✨ SUCCESS! You said: 'hello'
# 📝 Text length: 5 characters
#    ✅ Result: 'hello'
# ------------------------------
#
# 📝 Challenge 2: Say a long sentence about your favorite hobby
#
# 🎤 EXPERIMENT: Speech to Text
# ========================================
# 📢 Instructions:
# 1. Click 'Run' on this cell
# 2. When you see 'Listening...', start speaking
# 3. Speak clearly for 3-5 seconds
# 4. Watch the magic happen!
#
# 🎧 Listening... Speak now!
# (Speak clearly for 3-5 seconds)
# 🔄 Processing your speech...
#
# ✨ SUCCESS! You said: 'so my favorite hobby'
# 📝 Text length: 20 characters
#    ✅ Result: 'so my favorite hobby'
# ------------------------------
#
# 📝 Challenge 3: Try speaking very quietly
#
# 🎤 EXPERIMENT: Speech to Text
# ========================================
# 📢 Instructions:
# 1. Click 'Run' on this cell
# 2. When you see 'Listening...', start speaking
# 3. Speak clearly for 3-5 seconds
# 4. Watch the magic happen!
#
# 🎧 Listening... Speak now!
# (Speak clearly for 3-5 seconds)
# 🔄 Processing your speech...
#
# ✨ SUCCESS! You said: 'hey how's it going'
# 📝 Text length: 18 characters
#    ✅ Result: 'hey how's it going'
# ------------------------------
#
# 📝 Challenge 4: Try speaking very fast
#
# 🎤 EXPERIMENT: Speech to Text
# ========================================
# 📢 Instructions:
# 1. Click 'Run' on this cell
# 2. When you see 'Listening...', start speaking
# 3. Speak clearly for 3-5 seconds
# 4. Watch the magic happen!
#
# 🎧 Listening... Speak now!
# (Speak clearly for 3-5 seconds)
# 🔄 Processing your speech...
#
# ✨ SUCCESS! You said: 'can you drink a cup of water'
# 📝 Text length: 28 characters
#    ✅ Result: 'can you drink a cup of water'
# ------------------------------
#
# 📝 Challenge 5: Say some numbers like 'twelve thirty-four'
#
# 🎤 EXPERIMENT: Speech to Text
# ========================================
# 📢 Instructions:
# 1. Click 'Run' on this cell
# 2. When you see 'Listening...', start speaking
# 3. Speak clearly for 3-5 seconds
# 4. Watch the magic happen!
#
# 🎧 Listening... Speak now!
# (Speak clearly for 3-5 seconds)
# 🔄 Processing your speech...
#
# ✨ SUCCESS! You said: '12:34'
# 📝 Text length: 5 characters
#    ✅ Result: '12:34'
# ------------------------------
#
# 📊 CHALLENGE SUMMARY:
# Challenge 1: ✅ Success
# Challenge 2: ✅ Success
# Challenge 3: ✅ Success
# Challenge 4: ✅ Success
# Challenge 5: ✅ Success

# %% [markdown]
# ## 🗣️ Step 3: Understanding Text-to-Speech (TTS)
#
# Now let's give our computer a voice! Text-to-Speech is like giving your computer a mouth.
#
# **The Process:**
# 1. Computer receives text
# 2. AI analyzes the words and grammar
# 3. Determines pronunciation and emphasis
# 4. Generates sound waves that match human speech
# 5. Plays the audio through speakers

# %%
import pyttsx3

print("🗣️ Setting up Text-to-Speech...")

# Initialize the TTS engine
tts_engine = pyttsx3.init()

# Let's explore the available voices
def explore_voices():
    """Discover what voices are available"""
    print("\n🎭 EXPLORING AVAILABLE VOICES")
    print("=" * 40)
    
    voices = tts_engine.getProperty('voices')
    print(f"🔍 Found {len(voices)} voices on your system:")
    
    for i, voice in enumerate(voices):
        # Get voice info
        name = voice.name
        gender = "Female" if "female" in name.lower() else "Male" if "male" in name.lower() else "Unknown"
        language = voice.languages[0] if voice.languages else "Unknown"
        
        print(f"\n  Voice {i}:")
        print(f"    Name: {name}")
        print(f"    Gender: {gender}")
        print(f"    Language: {language}")
        print(f"    ID: {voice.id}")
    
    return voices

# Explore available voices
available_voices = explore_voices()
# Out:
# 🗣️ Setting up Text-to-Speech...
#
# 🎭 EXPLORING AVAILABLE VOICES
# ========================================
# 🔍 Found 177 voices on your system:
#
#   Voice 0:
#     Name: Albert
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Albert
#
#   Voice 1:
#     Name: Alice
#     Gender: Unknown
#     Language: it_IT
#     ID: com.apple.voice.compact.it-IT.Alice
#
#   Voice 2:
#     Name: Alva
#     Gender: Unknown
#     Language: sv_SE
#     ID: com.apple.voice.compact.sv-SE.Alva
#
#   Voice 3:
#     Name: Amélie
#     Gender: Unknown
#     Language: fr_CA
#     ID: com.apple.voice.compact.fr-CA.Amelie
#
#   Voice 4:
#     Name: Amira
#     Gender: Unknown
#     Language: ms_MY
#     ID: com.apple.voice.compact.ms-MY.Amira
#
#   Voice 5:
#     Name: Anna
#     Gender: Unknown
#     Language: de_DE
#     ID: com.apple.voice.compact.de-DE.Anna
#
#   Voice 6:
#     Name: Bad News
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.BadNews
#
#   Voice 7:
#     Name: Bahh
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Bahh
#
#   Voice 8:
#     Name: Bells
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Bells
#
#   Voice 9:
#     Name: Boing
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Boing
#
#   Voice 10:
#     Name: Bubbles
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Bubbles
#
#   Voice 11:
#     Name: Carmit
#     Gender: Unknown
#     Language: he_IL
#     ID: com.apple.voice.compact.he-IL.Carmit
#
#   Voice 12:
#     Name: Cellos
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Cellos
#
#   Voice 13:
#     Name: Damayanti
#     Gender: Unknown
#     Language: id_ID
#     ID: com.apple.voice.compact.id-ID.Damayanti
#
#   Voice 14:
#     Name: Daniel
#     Gender: Unknown
#     Language: en_GB
#     ID: com.apple.voice.compact.en-GB.Daniel
#
#   Voice 15:
#     Name: Daria
#     Gender: Unknown
#     Language: bg_BG
#     ID: com.apple.voice.compact.bg-BG.Daria
#
#   Voice 16:
#     Name: Wobble
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Deranged
#
#   Voice 17:
#     Name: Eddy (German (Germany))
#     Gender: Unknown
#     Language: de_DE
#     ID: com.apple.eloquence.de-DE.Eddy
#
#   Voice 18:
#     Name: Eddy (English (UK))
#     Gender: Unknown
#     Language: en_GB
#     ID: com.apple.eloquence.en-GB.Eddy
#
#   Voice 19:
#     Name: Eddy (English (US))
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.eloquence.en-US.Eddy
#
#   Voice 20:
#     Name: Eddy (Spanish (Spain))
#     Gender: Unknown
#     Language: es_ES
#     ID: com.apple.eloquence.es-ES.Eddy
#
#   Voice 21:
#     Name: Eddy (Spanish (Mexico))
#     Gender: Unknown
#     Language: es_MX
#     ID: com.apple.eloquence.es-MX.Eddy
#
#   Voice 22:
#     Name: Eddy (Finnish (Finland))
#     Gender: Unknown
#     Language: fi_FI
#     ID: com.apple.eloquence.fi-FI.Eddy
#
#   Voice 23:
#     Name: Eddy (French (Canada))
#     Gender: Unknown
#     Language: fr_CA
#     ID: com.apple.eloquence.fr-CA.Eddy
#
#   Voice 24:
#     Name: Eddy (French (France))
#     Gender: Unknown
#     Language: fr_FR
#     ID: com.apple.eloquence.fr-FR.Eddy
#
#   Voice 25:
#     Name: Eddy (Italian (Italy))
#     Gender: Unknown
#     Language: it_IT
#     ID: com.apple.eloquence.it-IT.Eddy
#
#   Voice 26:
#     Name: Eddy (Japanese (Japan))
#     Gender: Unknown
#     Language: ja_JP
#     ID: com.apple.eloquence.ja-JP.Eddy
#
#   Voice 27:
#     Name: Eddy (Korean (South Korea))
#     Gender: Unknown
#     Language: ko_KR
#     ID: com.apple.eloquence.ko-KR.Eddy
#
#   Voice 28:
#     Name: Eddy (Portuguese (Brazil))
#     Gender: Unknown
#     Language: pt_BR
#     ID: com.apple.eloquence.pt-BR.Eddy
#
#   Voice 29:
#     Name: Eddy (Chinese (China mainland))
#     Gender: Unknown
#     Language: zh_CN
#     ID: com.apple.eloquence.zh-CN.Eddy
#
#   Voice 30:
#     Name: Eddy (Chinese (Taiwan))
#     Gender: Unknown
#     Language: zh_TW
#     ID: com.apple.eloquence.zh-TW.Eddy
#
#   Voice 31:
#     Name: Ellen
#     Gender: Unknown
#     Language: nl_BE
#     ID: com.apple.voice.compact.nl-BE.Ellen
#
#   Voice 32:
#     Name: Flo (German (Germany))
#     Gender: Unknown
#     Language: de_DE
#     ID: com.apple.eloquence.de-DE.Flo
#
#   Voice 33:
#     Name: Flo (English (UK))
#     Gender: Unknown
#     Language: en_GB
#     ID: com.apple.eloquence.en-GB.Flo
#
#   Voice 34:
#     Name: Flo (English (US))
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.eloquence.en-US.Flo
#
#   Voice 35:
#     Name: Flo (Spanish (Spain))
#     Gender: Unknown
#     Language: es_ES
#     ID: com.apple.eloquence.es-ES.Flo
#
#   Voice 36:
#     Name: Flo (Spanish (Mexico))
#     Gender: Unknown
#     Language: es_MX
#     ID: com.apple.eloquence.es-MX.Flo
#
#   Voice 37:
#     Name: Flo (Finnish (Finland))
#     Gender: Unknown
#     Language: fi_FI
#     ID: com.apple.eloquence.fi-FI.Flo
#
#   Voice 38:
#     Name: Flo (French (Canada))
#     Gender: Unknown
#     Language: fr_CA
#     ID: com.apple.eloquence.fr-CA.Flo
#
#   Voice 39:
#     Name: Flo (French (France))
#     Gender: Unknown
#     Language: fr_FR
#     ID: com.apple.eloquence.fr-FR.Flo
#
#   Voice 40:
#     Name: Flo (Italian (Italy))
#     Gender: Unknown
#     Language: it_IT
#     ID: com.apple.eloquence.it-IT.Flo
#
#   Voice 41:
#     Name: Flo (Japanese (Japan))
#     Gender: Unknown
#     Language: ja_JP
#     ID: com.apple.eloquence.ja-JP.Flo
#
#   Voice 42:
#     Name: Flo (Korean (South Korea))
#     Gender: Unknown
#     Language: ko_KR
#     ID: com.apple.eloquence.ko-KR.Flo
#
#   Voice 43:
#     Name: Flo (Portuguese (Brazil))
#     Gender: Unknown
#     Language: pt_BR
#     ID: com.apple.eloquence.pt-BR.Flo
#
#   Voice 44:
#     Name: Flo (Chinese (China mainland))
#     Gender: Unknown
#     Language: zh_CN
#     ID: com.apple.eloquence.zh-CN.Flo
#
#   Voice 45:
#     Name: Flo (Chinese (Taiwan))
#     Gender: Unknown
#     Language: zh_TW
#     ID: com.apple.eloquence.zh-TW.Flo
#
#   Voice 46:
#     Name: Fred
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Fred
#
#   Voice 47:
#     Name: Good News
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.GoodNews
#
#   Voice 48:
#     Name: Grandma (German (Germany))
#     Gender: Unknown
#     Language: de_DE
#     ID: com.apple.eloquence.de-DE.Grandma
#
#   Voice 49:
#     Name: Grandma (English (UK))
#     Gender: Unknown
#     Language: en_GB
#     ID: com.apple.eloquence.en-GB.Grandma
#
#   Voice 50:
#     Name: Grandma (English (US))
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.eloquence.en-US.Grandma
#
#   Voice 51:
#     Name: Grandma (Spanish (Spain))
#     Gender: Unknown
#     Language: es_ES
#     ID: com.apple.eloquence.es-ES.Grandma
#
#   Voice 52:
#     Name: Grandma (Spanish (Mexico))
#     Gender: Unknown
#     Language: es_MX
#     ID: com.apple.eloquence.es-MX.Grandma
#
#   Voice 53:
#     Name: Grandma (Finnish (Finland))
#     Gender: Unknown
#     Language: fi_FI
#     ID: com.apple.eloquence.fi-FI.Grandma
#
#   Voice 54:
#     Name: Grandma (French (Canada))
#     Gender: Unknown
#     Language: fr_CA
#     ID: com.apple.eloquence.fr-CA.Grandma
#
#   Voice 55:
#     Name: Grandma (French (France))
#     Gender: Unknown
#     Language: fr_FR
#     ID: com.apple.eloquence.fr-FR.Grandma
#
#   Voice 56:
#     Name: Grandma (Italian (Italy))
#     Gender: Unknown
#     Language: it_IT
#     ID: com.apple.eloquence.it-IT.Grandma
#
#   Voice 57:
#     Name: Grandma (Japanese (Japan))
#     Gender: Unknown
#     Language: ja_JP
#     ID: com.apple.eloquence.ja-JP.Grandma
#
#   Voice 58:
#     Name: Grandma (Korean (South Korea))
#     Gender: Unknown
#     Language: ko_KR
#     ID: com.apple.eloquence.ko-KR.Grandma
#
#   Voice 59:
#     Name: Grandma (Portuguese (Brazil))
#     Gender: Unknown
#     Language: pt_BR
#     ID: com.apple.eloquence.pt-BR.Grandma
#
#   Voice 60:
#     Name: Grandma (Chinese (China mainland))
#     Gender: Unknown
#     Language: zh_CN
#     ID: com.apple.eloquence.zh-CN.Grandma
#
#   Voice 61:
#     Name: Grandma (Chinese (Taiwan))
#     Gender: Unknown
#     Language: zh_TW
#     ID: com.apple.eloquence.zh-TW.Grandma
#
#   Voice 62:
#     Name: Grandpa (German (Germany))
#     Gender: Unknown
#     Language: de_DE
#     ID: com.apple.eloquence.de-DE.Grandpa
#
#   Voice 63:
#     Name: Grandpa (English (UK))
#     Gender: Unknown
#     Language: en_GB
#     ID: com.apple.eloquence.en-GB.Grandpa
#
#   Voice 64:
#     Name: Grandpa (English (US))
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.eloquence.en-US.Grandpa
#
#   Voice 65:
#     Name: Grandpa (Spanish (Spain))
#     Gender: Unknown
#     Language: es_ES
#     ID: com.apple.eloquence.es-ES.Grandpa
#
#   Voice 66:
#     Name: Grandpa (Spanish (Mexico))
#     Gender: Unknown
#     Language: es_MX
#     ID: com.apple.eloquence.es-MX.Grandpa
#
#   Voice 67:
#     Name: Grandpa (Finnish (Finland))
#     Gender: Unknown
#     Language: fi_FI
#     ID: com.apple.eloquence.fi-FI.Grandpa
#
#   Voice 68:
#     Name: Grandpa (French (Canada))
#     Gender: Unknown
#     Language: fr_CA
#     ID: com.apple.eloquence.fr-CA.Grandpa
#
#   Voice 69:
#     Name: Grandpa (French (France))
#     Gender: Unknown
#     Language: fr_FR
#     ID: com.apple.eloquence.fr-FR.Grandpa
#
#   Voice 70:
#     Name: Grandpa (Italian (Italy))
#     Gender: Unknown
#     Language: it_IT
#     ID: com.apple.eloquence.it-IT.Grandpa
#
#   Voice 71:
#     Name: Grandpa (Japanese (Japan))
#     Gender: Unknown
#     Language: ja_JP
#     ID: com.apple.eloquence.ja-JP.Grandpa
#
#   Voice 72:
#     Name: Grandpa (Korean (South Korea))
#     Gender: Unknown
#     Language: ko_KR
#     ID: com.apple.eloquence.ko-KR.Grandpa
#
#   Voice 73:
#     Name: Grandpa (Portuguese (Brazil))
#     Gender: Unknown
#     Language: pt_BR
#     ID: com.apple.eloquence.pt-BR.Grandpa
#
#   Voice 74:
#     Name: Grandpa (Chinese (China mainland))
#     Gender: Unknown
#     Language: zh_CN
#     ID: com.apple.eloquence.zh-CN.Grandpa
#
#   Voice 75:
#     Name: Grandpa (Chinese (Taiwan))
#     Gender: Unknown
#     Language: zh_TW
#     ID: com.apple.eloquence.zh-TW.Grandpa
#
#   Voice 76:
#     Name: Jester
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Hysterical
#
#   Voice 77:
#     Name: Ioana
#     Gender: Unknown
#     Language: ro_RO
#     ID: com.apple.voice.compact.ro-RO.Ioana
#
#   Voice 78:
#     Name: Jacques
#     Gender: Unknown
#     Language: fr_FR
#     ID: com.apple.eloquence.fr-FR.Jacques
#
#   Voice 79:
#     Name: Joana
#     Gender: Unknown
#     Language: pt_PT
#     ID: com.apple.voice.compact.pt-PT.Joana
#
#   Voice 80:
#     Name: Junior
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Junior
#
#   Voice 81:
#     Name: Kanya
#     Gender: Unknown
#     Language: th_TH
#     ID: com.apple.voice.compact.th-TH.Kanya
#
#   Voice 82:
#     Name: Karen
#     Gender: Unknown
#     Language: en_AU
#     ID: com.apple.voice.compact.en-AU.Karen
#
#   Voice 83:
#     Name: Kathy
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Kathy
#
#   Voice 84:
#     Name: Kyoko
#     Gender: Unknown
#     Language: ja_JP
#     ID: com.apple.voice.compact.ja-JP.Kyoko
#
#   Voice 85:
#     Name: Lana
#     Gender: Unknown
#     Language: hr_HR
#     ID: com.apple.voice.compact.hr-HR.Lana
#
#   Voice 86:
#     Name: Laura
#     Gender: Unknown
#     Language: sk_SK
#     ID: com.apple.voice.compact.sk-SK.Laura
#
#   Voice 87:
#     Name: Lekha
#     Gender: Unknown
#     Language: hi_IN
#     ID: com.apple.voice.compact.hi-IN.Lekha
#
#   Voice 88:
#     Name: Lesya
#     Gender: Unknown
#     Language: uk_UA
#     ID: com.apple.voice.compact.uk-UA.Lesya
#
#   Voice 89:
#     Name: Linh
#     Gender: Unknown
#     Language: vi_VN
#     ID: com.apple.voice.compact.vi-VN.Linh
#
#   Voice 90:
#     Name: Luciana
#     Gender: Unknown
#     Language: pt_BR
#     ID: com.apple.voice.compact.pt-BR.Luciana
#
#   Voice 91:
#     Name: Majed
#     Gender: Unknown
#     Language: ar_001
#     ID: com.apple.voice.compact.ar-001.Maged
#
#   Voice 92:
#     Name: Tünde
#     Gender: Unknown
#     Language: hu_HU
#     ID: com.apple.voice.compact.hu-HU.Mariska
#
#   Voice 93:
#     Name: Meijia
#     Gender: Unknown
#     Language: zh_TW
#     ID: com.apple.voice.compact.zh-TW.Meijia
#
#   Voice 94:
#     Name: Melina
#     Gender: Unknown
#     Language: el_GR
#     ID: com.apple.voice.compact.el-GR.Melina
#
#   Voice 95:
#     Name: Milena
#     Gender: Unknown
#     Language: ru_RU
#     ID: com.apple.voice.compact.ru-RU.Milena
#
#   Voice 96:
#     Name: Moira
#     Gender: Unknown
#     Language: en_IE
#     ID: com.apple.voice.compact.en-IE.Moira
#
#   Voice 97:
#     Name: Mónica
#     Gender: Unknown
#     Language: es_ES
#     ID: com.apple.voice.compact.es-ES.Monica
#
#   Voice 98:
#     Name: Montse
#     Gender: Unknown
#     Language: ca_ES
#     ID: com.apple.voice.compact.ca-ES.Montserrat
#
#   Voice 99:
#     Name: Nora
#     Gender: Unknown
#     Language: nb_NO
#     ID: com.apple.voice.compact.nb-NO.Nora
#
#   Voice 100:
#     Name: Organ
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Organ
#
#   Voice 101:
#     Name: Paulina
#     Gender: Unknown
#     Language: es_MX
#     ID: com.apple.voice.compact.es-MX.Paulina
#
#   Voice 102:
#     Name: Superstar
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Princess
#
#   Voice 103:
#     Name: Ralph
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Ralph
#
#   Voice 104:
#     Name: Reed (German (Germany))
#     Gender: Unknown
#     Language: de_DE
#     ID: com.apple.eloquence.de-DE.Reed
#
#   Voice 105:
#     Name: Reed (English (UK))
#     Gender: Unknown
#     Language: en_GB
#     ID: com.apple.eloquence.en-GB.Reed
#
#   Voice 106:
#     Name: Reed (English (US))
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.eloquence.en-US.Reed
#
#   Voice 107:
#     Name: Reed (Spanish (Spain))
#     Gender: Unknown
#     Language: es_ES
#     ID: com.apple.eloquence.es-ES.Reed
#
#   Voice 108:
#     Name: Reed (Spanish (Mexico))
#     Gender: Unknown
#     Language: es_MX
#     ID: com.apple.eloquence.es-MX.Reed
#
#   Voice 109:
#     Name: Reed (Finnish (Finland))
#     Gender: Unknown
#     Language: fi_FI
#     ID: com.apple.eloquence.fi-FI.Reed
#
#   Voice 110:
#     Name: Reed (French (Canada))
#     Gender: Unknown
#     Language: fr_CA
#     ID: com.apple.eloquence.fr-CA.Reed
#
#   Voice 111:
#     Name: Reed (Italian (Italy))
#     Gender: Unknown
#     Language: it_IT
#     ID: com.apple.eloquence.it-IT.Reed
#
#   Voice 112:
#     Name: Reed (Japanese (Japan))
#     Gender: Unknown
#     Language: ja_JP
#     ID: com.apple.eloquence.ja-JP.Reed
#
#   Voice 113:
#     Name: Reed (Korean (South Korea))
#     Gender: Unknown
#     Language: ko_KR
#     ID: com.apple.eloquence.ko-KR.Reed
#
#   Voice 114:
#     Name: Reed (Portuguese (Brazil))
#     Gender: Unknown
#     Language: pt_BR
#     ID: com.apple.eloquence.pt-BR.Reed
#
#   Voice 115:
#     Name: Reed (Chinese (China mainland))
#     Gender: Unknown
#     Language: zh_CN
#     ID: com.apple.eloquence.zh-CN.Reed
#
#   Voice 116:
#     Name: Reed (Chinese (Taiwan))
#     Gender: Unknown
#     Language: zh_TW
#     ID: com.apple.eloquence.zh-TW.Reed
#
#   Voice 117:
#     Name: Rishi
#     Gender: Unknown
#     Language: en_IN
#     ID: com.apple.voice.compact.en-IN.Rishi
#
#   Voice 118:
#     Name: Rocko (German (Germany))
#     Gender: Unknown
#     Language: de_DE
#     ID: com.apple.eloquence.de-DE.Rocko
#
#   Voice 119:
#     Name: Rocko (English (UK))
#     Gender: Unknown
#     Language: en_GB
#     ID: com.apple.eloquence.en-GB.Rocko
#
#   Voice 120:
#     Name: Rocko (English (US))
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.eloquence.en-US.Rocko
#
#   Voice 121:
#     Name: Rocko (Spanish (Spain))
#     Gender: Unknown
#     Language: es_ES
#     ID: com.apple.eloquence.es-ES.Rocko
#
#   Voice 122:
#     Name: Rocko (Spanish (Mexico))
#     Gender: Unknown
#     Language: es_MX
#     ID: com.apple.eloquence.es-MX.Rocko
#
#   Voice 123:
#     Name: Rocko (Finnish (Finland))
#     Gender: Unknown
#     Language: fi_FI
#     ID: com.apple.eloquence.fi-FI.Rocko
#
#   Voice 124:
#     Name: Rocko (French (Canada))
#     Gender: Unknown
#     Language: fr_CA
#     ID: com.apple.eloquence.fr-CA.Rocko
#
#   Voice 125:
#     Name: Rocko (French (France))
#     Gender: Unknown
#     Language: fr_FR
#     ID: com.apple.eloquence.fr-FR.Rocko
#
#   Voice 126:
#     Name: Rocko (Italian (Italy))
#     Gender: Unknown
#     Language: it_IT
#     ID: com.apple.eloquence.it-IT.Rocko
#
#   Voice 127:
#     Name: Rocko (Japanese (Japan))
#     Gender: Unknown
#     Language: ja_JP
#     ID: com.apple.eloquence.ja-JP.Rocko
#
#   Voice 128:
#     Name: Rocko (Korean (South Korea))
#     Gender: Unknown
#     Language: ko_KR
#     ID: com.apple.eloquence.ko-KR.Rocko
#
#   Voice 129:
#     Name: Rocko (Portuguese (Brazil))
#     Gender: Unknown
#     Language: pt_BR
#     ID: com.apple.eloquence.pt-BR.Rocko
#
#   Voice 130:
#     Name: Rocko (Chinese (China mainland))
#     Gender: Unknown
#     Language: zh_CN
#     ID: com.apple.eloquence.zh-CN.Rocko
#
#   Voice 131:
#     Name: Rocko (Chinese (Taiwan))
#     Gender: Unknown
#     Language: zh_TW
#     ID: com.apple.eloquence.zh-TW.Rocko
#
#   Voice 132:
#     Name: Samantha
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.voice.compact.en-US.Samantha
#
#   Voice 133:
#     Name: Sandy (German (Germany))
#     Gender: Unknown
#     Language: de_DE
#     ID: com.apple.eloquence.de-DE.Sandy
#
#   Voice 134:
#     Name: Sandy (English (UK))
#     Gender: Unknown
#     Language: en_GB
#     ID: com.apple.eloquence.en-GB.Sandy
#
#   Voice 135:
#     Name: Sandy (English (US))
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.eloquence.en-US.Sandy
#
#   Voice 136:
#     Name: Sandy (Spanish (Spain))
#     Gender: Unknown
#     Language: es_ES
#     ID: com.apple.eloquence.es-ES.Sandy
#
#   Voice 137:
#     Name: Sandy (Spanish (Mexico))
#     Gender: Unknown
#     Language: es_MX
#     ID: com.apple.eloquence.es-MX.Sandy
#
#   Voice 138:
#     Name: Sandy (Finnish (Finland))
#     Gender: Unknown
#     Language: fi_FI
#     ID: com.apple.eloquence.fi-FI.Sandy
#
#   Voice 139:
#     Name: Sandy (French (Canada))
#     Gender: Unknown
#     Language: fr_CA
#     ID: com.apple.eloquence.fr-CA.Sandy
#
#   Voice 140:
#     Name: Sandy (French (France))
#     Gender: Unknown
#     Language: fr_FR
#     ID: com.apple.eloquence.fr-FR.Sandy
#
#   Voice 141:
#     Name: Sandy (Italian (Italy))
#     Gender: Unknown
#     Language: it_IT
#     ID: com.apple.eloquence.it-IT.Sandy
#
#   Voice 142:
#     Name: Sandy (Japanese (Japan))
#     Gender: Unknown
#     Language: ja_JP
#     ID: com.apple.eloquence.ja-JP.Sandy
#
#   Voice 143:
#     Name: Sandy (Korean (South Korea))
#     Gender: Unknown
#     Language: ko_KR
#     ID: com.apple.eloquence.ko-KR.Sandy
#
#   Voice 144:
#     Name: Sandy (Portuguese (Brazil))
#     Gender: Unknown
#     Language: pt_BR
#     ID: com.apple.eloquence.pt-BR.Sandy
#
#   Voice 145:
#     Name: Sandy (Chinese (China mainland))
#     Gender: Unknown
#     Language: zh_CN
#     ID: com.apple.eloquence.zh-CN.Sandy
#
#   Voice 146:
#     Name: Sandy (Chinese (Taiwan))
#     Gender: Unknown
#     Language: zh_TW
#     ID: com.apple.eloquence.zh-TW.Sandy
#
#   Voice 147:
#     Name: Sara
#     Gender: Unknown
#     Language: da_DK
#     ID: com.apple.voice.compact.da-DK.Sara
#
#   Voice 148:
#     Name: Satu
#     Gender: Unknown
#     Language: fi_FI
#     ID: com.apple.voice.compact.fi-FI.Satu
#
#   Voice 149:
#     Name: Shelley (German (Germany))
#     Gender: Unknown
#     Language: de_DE
#     ID: com.apple.eloquence.de-DE.Shelley
#
#   Voice 150:
#     Name: Shelley (English (UK))
#     Gender: Unknown
#     Language: en_GB
#     ID: com.apple.eloquence.en-GB.Shelley
#
#   Voice 151:
#     Name: Shelley (English (US))
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.eloquence.en-US.Shelley
#
#   Voice 152:
#     Name: Shelley (Spanish (Spain))
#     Gender: Unknown
#     Language: es_ES
#     ID: com.apple.eloquence.es-ES.Shelley
#
#   Voice 153:
#     Name: Shelley (Spanish (Mexico))
#     Gender: Unknown
#     Language: es_MX
#     ID: com.apple.eloquence.es-MX.Shelley
#
#   Voice 154:
#     Name: Shelley (Finnish (Finland))
#     Gender: Unknown
#     Language: fi_FI
#     ID: com.apple.eloquence.fi-FI.Shelley
#
#   Voice 155:
#     Name: Shelley (French (Canada))
#     Gender: Unknown
#     Language: fr_CA
#     ID: com.apple.eloquence.fr-CA.Shelley
#
#   Voice 156:
#     Name: Shelley (French (France))
#     Gender: Unknown
#     Language: fr_FR
#     ID: com.apple.eloquence.fr-FR.Shelley
#
#   Voice 157:
#     Name: Shelley (Italian (Italy))
#     Gender: Unknown
#     Language: it_IT
#     ID: com.apple.eloquence.it-IT.Shelley
#
#   Voice 158:
#     Name: Shelley (Japanese (Japan))
#     Gender: Unknown
#     Language: ja_JP
#     ID: com.apple.eloquence.ja-JP.Shelley
#
#   Voice 159:
#     Name: Shelley (Korean (South Korea))
#     Gender: Unknown
#     Language: ko_KR
#     ID: com.apple.eloquence.ko-KR.Shelley
#
#   Voice 160:
#     Name: Shelley (Portuguese (Brazil))
#     Gender: Unknown
#     Language: pt_BR
#     ID: com.apple.eloquence.pt-BR.Shelley
#
#   Voice 161:
#     Name: Shelley (Chinese (China mainland))
#     Gender: Unknown
#     Language: zh_CN
#     ID: com.apple.eloquence.zh-CN.Shelley
#
#   Voice 162:
#     Name: Shelley (Chinese (Taiwan))
#     Gender: Unknown
#     Language: zh_TW
#     ID: com.apple.eloquence.zh-TW.Shelley
#
#   Voice 163:
#     Name: Sinji
#     Gender: Unknown
#     Language: zh_HK
#     ID: com.apple.voice.compact.zh-HK.Sinji
#
#   Voice 164:
#     Name: Tessa
#     Gender: Unknown
#     Language: en_ZA
#     ID: com.apple.voice.compact.en-ZA.Tessa
#
#   Voice 165:
#     Name: Thomas
#     Gender: Unknown
#     Language: fr_FR
#     ID: com.apple.voice.compact.fr-FR.Thomas
#
#   Voice 166:
#     Name: Tina
#     Gender: Unknown
#     Language: sl_SI
#     ID: com.apple.voice.compact.sl-SI.Tina
#
#   Voice 167:
#     Name: Tingting
#     Gender: Unknown
#     Language: zh_CN
#     ID: com.apple.voice.compact.zh-CN.Tingting
#
#   Voice 168:
#     Name: Trinoids
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Trinoids
#
#   Voice 169:
#     Name: Vani
#     Gender: Unknown
#     Language: ta_IN
#     ID: com.apple.voice.compact.ta-IN.Vani
#
#   Voice 170:
#     Name: Whisper
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Whisper
#
#   Voice 171:
#     Name: Xander
#     Gender: Unknown
#     Language: nl_NL
#     ID: com.apple.voice.compact.nl-NL.Xander
#
#   Voice 172:
#     Name: Yelda
#     Gender: Unknown
#     Language: tr_TR
#     ID: com.apple.voice.compact.tr-TR.Yelda
#
#   Voice 173:
#     Name: Yuna
#     Gender: Unknown
#     Language: ko_KR
#     ID: com.apple.voice.compact.ko-KR.Yuna
#
#   Voice 174:
#     Name: Zarvox
#     Gender: Unknown
#     Language: en_US
#     ID: com.apple.speech.synthesis.voice.Zarvox
#
#   Voice 175:
#     Name: Zosia
#     Gender: Unknown
#     Language: pl_PL
#     ID: com.apple.voice.compact.pl-PL.Zosia
#
#   Voice 176:
#     Name: Zuzana
#     Gender: Unknown
#     Language: cs_CZ
#     ID: com.apple.voice.compact.cs-CZ.Zuzana

# %% [markdown]
# ## 🎵 Experiment 2: Making Your Computer Talk
#
# Let's make our computer speak with different voices and settings!

# %%
def text_to_speech_demo():
    """Demonstrate text-to-speech with different settings"""
    print("\n🎪 TEXT-TO-SPEECH DEMO")
    print("=" * 35)
    
    test_message = "Hello! I am your voice agent. I can speak in different voices and speeds!"
    
    # Get current settings
    current_rate = tts_engine.getProperty('rate')
    current_volume = tts_engine.getProperty('volume')
    
    print(f"🎛️ Current settings:")
    print(f"   Speed: {current_rate} words per minute")
    print(f"   Volume: {current_volume}")
    
    # Demo 1: Normal speech
    print(f"\n🎤 Demo 1: Normal speech")
    tts_engine.setProperty('rate', 200)
    tts_engine.setProperty('volume', 0.8)
    tts_engine.say("Hello! This is normal speech.")
    tts_engine.runAndWait()
    
    # Demo 2: Slow speech
    print(f"\n🐌 Demo 2: Slow speech")
    tts_engine.setProperty('rate', 120)
    tts_engine.say("This... is... slow... speech.")
    tts_engine.runAndWait()
    
    # Demo 3: Fast speech
    print(f"\n🏃 Demo 3: Fast speech")
    tts_engine.setProperty('rate', 300)
    tts_engine.say("This is very fast speech! Can you understand me?")
    tts_engine.runAndWait()
    
    # Demo 4: Different voice (if available)
    if len(available_voices) > 1:
        print(f"\n👥 Demo 4: Different voice")
        tts_engine.setProperty('voice', available_voices[1].id)
        tts_engine.setProperty('rate', 200)
        tts_engine.say("Now I'm speaking with a different voice!")
        tts_engine.runAndWait()
        
        # Reset to first voice
        tts_engine.setProperty('voice', available_voices[0].id)
    
    print("\n✅ Text-to-Speech demo complete!")

# Run the demo
text_to_speech_demo()
# Out:
# 🎪 TEXT-TO-SPEECH DEMO
# ===================================
# 🎛️ Current settings:
#    Speed: 200.0 words per minute
#    Volume: 1.0
#
# 🎤 Demo 1: Normal speech
#
# 🐌 Demo 2: Slow speech
#
# 🏃 Demo 3: Fast speech
#
# 👥 Demo 4: Different voice
#
# ✅ Text-to-Speech demo complete!

# %% [markdown]
# ## 🛠️ Step 4: Building Our Voice Agent Class
#
# Now let's put everything together! We'll create a Voice Agent class that can listen, think, and speak.

# %%
import datetime
import random
import wikipedia
import speech_recognition as sr
import pyttsx3
import openai
import os
from dotenv import load_dotenv

class VoiceAgent:
    """A simple voice agent that can listen, process, and respond"""
    
    def __init__(self, name="Sophia", enable_tts=True):
        """Initialize the voice agent"""
        self.name = name
        self.recognizer = sr.Recognizer()
        self.microphone = sr.Microphone()
        
        # TTS control
        self.enable_tts = enable_tts
        self.voice_id = None
        self.voice_rate = 175
        self.voice_volume = 0.9
        
        # Find and store the best voice
        if self.enable_tts:
            self.find_best_voice()
        
        # Initialize OpenAI client for GPT-4o-mini
        self.setup_openai()
        
        # Conversation history for context
        self.conversation_history = []
        
        # Agent's knowledge and responses
        self.responses = {
            'greetings': [
                f"Hello! I'm {self.name}, your voice agent!",
                f"Hi there! {self.name} here, ready to help!",
                f"Greetings! I'm {self.name}. How can I assist you?"
            ],
            'farewell': [
                "Goodbye! It was nice talking with you!",
                "See you later! Have a great day!",
                "Farewell! Come back anytime!"
            ],
            'thanks': [
                "You're welcome! Happy to help!",
                "No problem at all!",
                "Glad I could assist you!"
            ],
            'unknown': [
                "I'm still learning. Could you try asking differently?",
                "That's interesting! I don't know about that yet.",
                "I'm not sure about that. Can you teach me?"
            ]
        }
        
        tts_status = "with voice enabled" if self.enable_tts else "in text-only mode"
        print(f"🤖 {self.name} is ready to help {tts_status}!")
    
    def find_best_voice(self):
        """Find and store the best US female voice"""
        try:
            temp_engine = pyttsx3.init()
            voices = temp_engine.getProperty('voices')
            
            if voices:
                print("🔍 Searching for US female voices...")
                
                # Priority 1: Look for US English female voices
                us_female_keywords = [
                    'english (united states)', 'en-us', 'usa', 'american',
                    'zira', 'cortana', 'eva', 'samantha', 'alex'
                ]
                
                for voice in voices:
                    voice_name = voice.name.lower()
                    voice_id = voice.id.lower()
                    
                    # Check if voice is US English and female
                    is_us = any(keyword in voice_name or keyword in voice_id for keyword in us_female_keywords)
                    is_female = any(keyword in voice_name for keyword in ['female', 'woman', 'girl', 'zira', 'cortana', 'eva', 'samantha'])
                    
                    if is_us and is_female:
                        self.voice_id = voice.id
                        print(f"🎭 Selected US female voice: {voice.name}")
                        break
                
                # Fallback to any female voice
                if not self.voice_id:
                    for voice in voices:
                        voice_name = voice.name.lower()
                        if any(keyword in voice_name for keyword in ['female', 'woman', 'girl', 'zira', 'samantha']):
                            self.voice_id = voice.id
                            print(f"🎭 Selected female voice: {voice.name}")
                            break
                
                # Final fallback
                if not self.voice_id and len(voices) > 1:
                    self.voice_id = voices[1].id
                    print(f"🎭 Fallback voice selected: {voices[1].name}")
            
            # Clean up temp engine
            temp_engine.stop()
            del temp_engine
            
        except Exception as e:
            print(f"⚠️ Voice detection error: {e}")
            self.voice_id = None
    
    def setup_openai(self):
        """Setup OpenAI API for GPT-4o-mini from .env file"""
        try:
            # Load environment variables from .env file
            load_dotenv()
            
            # Get API key from environment variable
            api_key = os.getenv('OPENAI_API_KEY')
            
            if not api_key:
                print("❌ OPENAI_API_KEY not found in .env file!")
                print("📝 Please add your API key to .env file:")
                print("   OPENAI_API_KEY=your_api_key_here")
                print("⚠️ Continuing without AI features. Using basic responses only.")
                self.openai_client = None
                return
            
            # Initialize OpenAI client with new API (v1.0+)
            self.openai_client = openai.OpenAI(api_key=api_key)
            print("✅ GPT-4o-mini connected successfully from .env file!")
            
        except ImportError:
            print("❌ python-dotenv not installed!")
            print("📦 Please install it: pip install python-dotenv")
            print("⚠️ Continuing without AI features. Using basic responses only.")
            self.openai_client = None
        except Exception as e:
            print(f"❌ Error setting up OpenAI: {e}")
            print("⚠️ Continuing without AI features. Using basic responses only.")
            self.openai_client = None
    
    def get_ai_response(self, user_input):
        """Get intelligent response from GPT-4o-mini"""
        if not self.openai_client:
            return None
        
        try:
            # Prepare conversation context
            messages = [
                {"role": "system", "content": "You are Sophia, a helpful and friendly voice assistant. Keep responses concise (1-3 sentences) since they will be spoken aloud. Use a warm, encouraging tone."}
            ]
            
            # Add recent conversation history for context
            for msg in self.conversation_history[-6:]:  # Last 6 messages for context
                messages.append(msg)
            
            # Add current user input
            messages.append({"role": "user", "content": user_input})
            
            # Get response from GPT-4o-mini using new API
            response = self.openai_client.chat.completions.create(
                model="gpt-4o-mini",
                messages=messages,
                max_tokens=150,  # Keep responses concise for speech
                temperature=0.7,  # Balanced creativity and consistency
            )
            
            ai_response = response.choices[0].message.content.strip()
            
            # Update conversation history
            self.conversation_history.append({"role": "user", "content": user_input})
            self.conversation_history.append({"role": "assistant", "content": ai_response})
            
            # Keep history manageable
            if len(self.conversation_history) > 20:
                self.conversation_history = self.conversation_history[-20:]
            
            return ai_response
            
        except Exception as e:
            print(f"❌ AI Error: {e}")
            return None
    
    def speak(self, text):
        """Convert text to speech or text-only mode"""
        print(f"🤖 {self.name}: {text}")
        
        if not self.enable_tts:
            print("📝 (Text-only mode)")
            return
        
        try:
            import subprocess
            import platform
            
            # Use system TTS instead of pyttsx3 for Jupyter
            system = platform.system()
            
            if system == "Darwin":  # macOS
                subprocess.run(["say", text], check=True)
            elif system == "Windows":
                subprocess.run(["powershell", "-Command", f"Add-Type -AssemblyName System.Speech; (New-Object System.Speech.Synthesis.SpeechSynthesizer).Speak('{text}')"], check=True)
            elif system == "Linux":
                subprocess.run(["espeak", text], check=True)
            else:
                print("🔇 System TTS not available on this platform")
                
        except Exception as e:
            print(f"🔇 System TTS error: {e}")
    
    def listen(self):
        """Listen to user speech and convert to text"""
        try:
            with self.microphone as source:
                print("🎧 Listening...")
                # Adjust for ambient noise
                self.recognizer.adjust_for_ambient_noise(source, duration=1)
                # Listen for audio
                audio = self.recognizer.listen(source, timeout=5, phrase_time_limit=5)
                
            print("🔄 Processing...")
            # Convert speech to text
            text = self.recognizer.recognize_google(audio).lower()
            print(f"👤 You said: '{text}'")
            return text
            
        except sr.WaitTimeoutError:
            self.speak("I didn't hear anything. Could you try again?")
            return ""
        except sr.UnknownValueError:
            self.speak("I couldn't understand that. Could you speak more clearly?")
            return ""
        except sr.RequestError:
            self.speak("Sorry, I'm having trouble with my speech recognition service.")
            return ""
    
    def get_current_time(self):
        """Get current time"""
        now = datetime.datetime.now()
        time_str = now.strftime("%I:%M %p")
        return f"The current time is {time_str}"
    
    def get_current_date(self):
        """Get current date"""
        today = datetime.date.today()
        date_str = today.strftime("%B %d, %Y")
        return f"Today is {date_str}"
    
    def search_wikipedia(self, query):
        """Search Wikipedia for information"""
        try:
            # Remove common words
            query = query.replace("tell me about", "").replace("what is", "").strip()
            if not query:
                return "I need something to search for!"
            
            print(f"🔍 Searching for: {query}")
            summary = wikipedia.summary(query, sentences=2)
            return summary
        except wikipedia.exceptions.DisambiguationError:
            return f"There are multiple entries for {query}. Could you be more specific?"
        except wikipedia.exceptions.PageError:
            return f"I couldn't find information about {query}."
        except:
            return "I had trouble searching for that information."
    
    def simple_math(self, command):
        """Perform simple math operations"""
        try:
            # Replace words with symbols
            command = command.replace("plus", "+").replace("add", "+")
            command = command.replace("minus", "-").replace("subtract", "-")
            command = command.replace("times", "*").replace("multiply", "*")
            command = command.replace("divided by", "/").replace("divide", "/")
            
            # Extract numbers and operation
            words = command.split()
            numbers = []
            operation = None
            
            for word in words:
                if word.isdigit():
                    numbers.append(int(word))
                elif word in ['+', '-', '*', '/']:
                    operation = word
            
            if len(numbers) == 2 and operation:
                if operation == '+':
                    result = numbers[0] + numbers[1]
                elif operation == '-':
                    result = numbers[0] - numbers[1]
                elif operation == '*':
                    result = numbers[0] * numbers[1]
                elif operation == '/':
                    if numbers[1] != 0:
                        result = numbers[0] / numbers[1]
                    else:
                        return "I can't divide by zero!"
                
                return f"{numbers[0]} {operation} {numbers[1]} equals {result}"
            else:
                return "I need two numbers and an operation to calculate."
                
        except:
            return "I couldn't understand that math problem."
    
    def process_command(self, command):
        """Process user command and generate response with AI integration"""
        command = command.lower().strip()
        
        # Try AI for complex or conversational queries first
        if self.openai_client:
            # Use AI for these types of queries
            ai_triggers = [
                'how are you', 'tell me a story', 'what do you think', 'explain', 'why', 
                'how does', 'can you', 'do you', 'what would', 'i feel', 'i think',
                'opinion', 'advice', 'recommend', 'suggest', 'weather', 'founded',
                'who founded', 'how to', 'what happened', 'when did'
            ]
            
            # Use AI if query is long or contains AI trigger words
            use_ai = (len(command.split()) > 6 or 
                     any(trigger in command for trigger in ai_triggers) or
                     command.endswith('?') or
                     '?' in command)
            
            if use_ai:
                print("🧠 Using AI for intelligent response...")
                ai_response = self.get_ai_response(command)
                if ai_response:
                    return ai_response
        
        # Basic command processing (fast responses)
        if any(word in command for word in ['hello', 'hi', 'hey', 'good morning', 'good afternoon']):
            return random.choice(self.responses['greetings'])
        
        elif any(word in command for word in ['goodbye', 'bye', 'see you', 'farewell']):
            return random.choice(self.responses['farewell'])
        
        elif any(word in command for word in ['thank', 'thanks', 'appreciate']):
            return random.choice(self.responses['thanks'])
        
        elif 'time' in command:
            return self.get_current_time()
        
        elif 'date' in command or 'today' in command:
            return self.get_current_date()
        
        elif any(word in command for word in ['plus', 'minus', 'times', 'divided', 'add', 'subtract', 'multiply', 'divide']) and any(char.isdigit() for char in command):
            return self.simple_math(command)
        
        elif any(phrase in command for phrase in ['tell me about', 'what is', 'who is', 'search for']):
            return self.search_wikipedia(command)
        
        elif 'your name' in command or 'who are you' in command:
            return f"I'm {self.name}, your personal voice agent! I can help you with time, dates, simple math, and general information."
        
        elif 'help' in command or 'what can you do' in command:
            return "I can tell you the time and date, do simple math, search for information, and have conversations with you! Try asking me anything!"
        
        else:
            return random.choice(self.responses['unknown'])

# Create agents for different purposes
agent = VoiceAgent("Sophia", enable_tts=False)  # For testing in Jupyter
agent_with_voice = VoiceAgent("Sophia", enable_tts=True)  # For real conversations

# Test function
def test_voice_agent():
    """Test the voice agent with sample commands (text-only for Jupyter)"""
    print("🧪 TESTING OUR VOICE AGENT (Text-Only Mode)")
    print("=" * 40)
    
    test_commands = [
        "hello",
        "what time is it",
        "what is today's date",
        "what is 15 plus 27",
        "tell me about artificial intelligence",
        "what can you do",
        "how are you feeling today",  # This should trigger AI
        "thank you",
        "goodbye"
    ]
    
    for i, command in enumerate(test_commands, 1):
        print(f"\n🔬 Test {i}: '{command}'")
        response = agent.process_command(command)
        agent.speak(response)
        print("-" * 30)

# Voice conversation function
def start_voice_conversation():
    """Start a real voice conversation with TTS enabled"""
    print("🎉 Starting Voice Conversation with TTS!")
    print("Say 'goodbye' to end the conversation.")
    
    agent_with_voice.speak("Hello! I'm ready to have a conversation with you!")
    
    conversation_count = 0
    max_conversations = 10
    
    while conversation_count < max_conversations:
        user_input = agent_with_voice.listen()
        
        if not user_input:
            continue
            
        if any(word in user_input for word in ['goodbye', 'bye', 'exit', 'quit']):
            agent_with_voice.speak("Goodbye! It was great talking with you!")
            break
        
        response = agent_with_voice.process_command(user_input)
        agent_with_voice.speak(response)
        
        conversation_count += 1
        print(f"💬 Conversation {conversation_count}/{max_conversations}")
        print("-" * 30)
    
    if conversation_count >= max_conversations:
        agent_with_voice.speak("We've had such a wonderful conversation! Let's chat again soon!")
    
    print("\n✅ Conversation ended!")
# Out:
# ✅ GPT-4o-mini connected successfully from .env file!
# 🤖 Sophia is ready to help in text-only mode!
# 🔍 Searching for US female voices...
# 🎭 Selected US female voice: Samantha
# ✅ GPT-4o-mini connected successfully from .env file!
# 🤖 Sophia is ready to help with voice enabled!

# %% [markdown]
# ## 🎮 Step 5: Testing Our Voice Agent
#
#  Let's test our voice agent with different types of commands!

# %%
# test_voice_agent()

start_voice_conversation()
# Out:
# 🧪 TESTING OUR VOICE AGENT (Text-Only Mode)
# ========================================
#
# 🔬 Test 1: 'hello'
# 🤖 Sophia: Greetings! I'm Sophia. How can I assist you?
# 📝 (Text-only mode)
# ------------------------------
#
# 🔬 Test 2: 'what time is it'
# 🤖 Sophia: The current time is 01:18 PM
# 📝 (Text-only mode)
# ------------------------------
#
# 🔬 Test 3: 'what is today's date'
# 🤖 Sophia: Today is June 29, 2025
# 📝 (Text-only mode)
# ------------------------------
#
# 🔬 Test 4: 'what is 15 plus 27'
# 🤖 Sophia: 15 + 27 equals 42
# 📝 (Text-only mode)
# ------------------------------
#
# 🔬 Test 5: 'tell me about artificial intelligence'
# 🔍 Searching for: artificial intelligence
# 🤖 Sophia: Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.
# 📝 (Text-only mode)
# ------------------------------
#
# 🔬 Test 6: 'what can you do'
# 🧠 Using AI for intelligent response...
# 🤖 Sophia: I can help you find information, answer questions, give reminders, and offer friendly suggestions. Just let me know what you need!
# 📝 (Text-only mode)
# ------------------------------
#
# 🔬 Test 7: 'how are you feeling today'
# 🧠 Using AI for intelligent response...
# 🤖 Sophia: I’m feeling great and ready to help you! How about you?
# 📝 (Text-only mode)
# ------------------------------
#
# 🔬 Test 8: 'thank you'
# 🤖 Sophia: You're welcome! Happy to help!
# 📝 (Text-only mode)
# ------------------------------
#
# 🔬 Test 9: 'goodbye'
# 🤖 Sophia: See you later! Have a great day!
# 📝 (Text-only mode)
# ------------------------------

# %% [markdown]
# ## 🎯 Step 6: Your Turn - Customize Your Agent!
#
# Now it's time to make your voice agent unique! Try these customizations:

# %%
# 🎨 CUSTOMIZATION PLAYGROUND
# ===========================

# 1. Change your agent's name
my_agent = VoiceAgent("YourNameHere")  # Change this!

# 2. Add new responses
def add_custom_responses():
    """Add your own custom responses"""
    
    # Add jokes
    jokes = [
        "Why don't scientists trust atoms? Because they make up everything!",
        "What do you call a bear with no teeth? A gummy bear!",
        "Why did the math book look so sad? Because it had too many problems!"
    ]
    
    # Add facts about yourself
    personal_facts = [
        "I was created by an awesome Class 9 student!",
        "I love learning new things every day!",
        "My favorite subject is computer science!"
    ]
    
    my_agent.responses['jokes'] = jokes
    my_agent.responses['personal'] = personal_facts

# 3. Add new functionality
def enhanced_process_command(self, command):
    """Enhanced command processing with new features"""
    command = command.lower().strip()
    
    # Original processing
    original_response = VoiceAgent.process_command(self, command)
    
    # New features
    if 'joke' in command or 'funny' in command:
        return random.choice(self.responses.get('jokes', ['I need to learn some jokes!']))
    
    elif 'about you' in command or 'about yourself' in command:
        return random.choice(self.responses.get('personal', ['I am a voice agent!']))
    
    elif 'weather' in command:
        return "I don't have access to weather data yet, but you could add that feature!"
    
    elif 'favorite' in command:
        favorites = [
            "My favorite programming language is Python!",
            "I love helping students learn about technology!",
            "My favorite time is when I'm talking with you!"
        ]
        return random.choice(favorites)
    
    else:
        return original_response

# Apply customizations
add_custom_responses()
# Replace the method (advanced Python technique)
VoiceAgent.process_command = enhanced_process_command

print("🎨 Your agent has been customized!")
print("Try asking your agent:")
print("- 'Tell me a joke'")
print("- 'What's your favorite color?'")
print("- 'Tell me about yourself'")
# Out:
# 🔍 Searching for US female voices...
# 🎭 Selected US female voice: Samantha
# ✅ GPT-4o-mini connected successfully from .env file!
# 🤖 YourNameHere is ready to help with voice enabled!
# 🎨 Your agent has been customized!
# Try asking your agent:
# - 'Tell me a joke'
# - 'What's your favorite color?'
# - 'Tell me about yourself'

# %% [markdown]
# ## 🏆 Step 7: Final Challenge - Build Your Feature!
#
# Time for the ultimate challenge! Add your own unique feature to the voice agent.

# %%
# 🎯 YOUR CHALLENGE: Add a new feature!
# ====================================

def your_custom_feature():
    """
    YOUR TURN: Create a unique feature for your voice agent!
    
    Ideas:
    1. Password generator
    2. Random compliment generator
    3. Study reminder system
    4. Simple game (like 20 questions)
    5. Unit converter (inches to cm, etc.)
    6. Random fact generator
    7. Motivational quotes
    
    Fill in this function with your code!
    """
    
    # Example: Random motivational quotes
    motivational_quotes = [
        "The future belongs to those who learn more skills and combine them in creative ways!",
        "Every expert was once a beginner. Keep learning!",
        "Technology is best when it brings people together!",
        "The only way to do great work is to love what you do!",
        "Innovation distinguishes between a leader and a follower!"
    ]
    
    # Your code here!
    feature_name = "Motivational Quotes"  # Change this
    
    print(f"🌟 Your custom feature: {feature_name}")
    
    # Example implementation
    quote = random.choice(motivational_quotes)
    return f"Here's some motivation for you: {quote}"

# Test your feature
my_feature_result = your_custom_feature()
print(my_feature_result)

# Now integrate it into your agent by modifying the process_command function!
# Out:
# 🌟 Your custom feature: Motivational Quotes
# Here's some motivation for you: Innovation distinguishes between a leader and a follower!

# %% [markdown]
# ## 📊 Step 10: Understanding How It All Works
#
# Let's recap what we've built and understand the technology behind it!
#
# ### 🔬 UNDERSTANDING VOICE AGENT TECHNOLOGY
# ==================================================
#
# 🔧 Speech Recognition (ASR)
# ------------------------
# 📝 Converts your speech into text that computers can understand
#
# 🔄 Process:
#    1. Microphone captures sound waves from your voice
#    2. Audio is converted to digital format
#    3. AI models analyze patterns in the audio
#    4. System matches patterns to known words
#    5. Returns the most likely text transcription
#
# 🌍 Real-world applications: Used in Siri, Google Assistant, Alexa, voice typing
#
#
# 🔧 Text-to-Speech (TTS)
# --------------------
# 📝 Converts text into natural-sounding speech
#
# 🔄 Process:
#    1. System analyzes the text for meaning and grammar
#    2. Determines correct pronunciation for each word
#    3. Applies natural rhythm and intonation
#    4. Generates audio waveforms
#    5. Plays the speech through speakers
#
# 🌍 Real-world applications: GPS navigation, accessibility tools, audiobooks, virtual assistants
#
#
# 🔧 Natural Language Processing
# ---------------------------
# 📝 Helps computers understand the meaning behind words
#
# 🔄 Process:
#    1. Breaks down sentences into individual words
#    2. Identifies the intent (what user wants)
#    3. Extracts key information (entities)
#    4. Determines appropriate response
#    5. Generates helpful output
#
# 🌍 Real-world applications: Chatbots, language translation, sentiment analysis
